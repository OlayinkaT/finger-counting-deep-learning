# %% [markdown]
# Importing Necessary Packages

# %%
import pandas as pd
import numpy as np
from PIL import Image
from PIL import UnidentifiedImageError
import os

import torch
import torch.nn as nn
from torch.utils.data import random_split
from torch.utils.data import Dataset, DataLoader, Subset
from torch.utils.data.dataloader import default_collate

import torchvision
from torchvision import datasets, transforms
from torchvision.datasets import DatasetFolder
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# This is for the progress bar
from tqdm.auto import tqdm
# This is for ploting
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset.git
# Out:
# Cloning into 'Human-Robot_Finger-Counting_Dataset'...
# remote: Enumerating objects: 12476, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 12476 (delta 8), reused 5 (delta 1), pack-reused 12454 (from 1)
# Receiving objects: 100% (12476/12476), 474.51 MiB | 16.52 MiB/s, done.
# Resolving deltas: 100% (2435/2435), done.
# Updating files: 100% (28820/28820), done.

# %%
# !ls /content/Human-Robot_Finger-Counting_Dataset
# Out:
# Backgrounds  Example_Datasets  LICENCE	Raw_Images  README.md  Toolbox

# %%
dataset_path = 'Human-Robot_Finger-Counting_Dataset/Example_Datasets/Combined_Fingers_2000_400_400'

# %%
dataset = datasets.ImageFolder(root=dataset_path)
len(dataset)
# Out:
# 5200

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=30),
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
train_dir = os.path.join(dataset_path, 'training_set')
test_dir = os.path.join(dataset_path, 'testing_set')
validation_dir = os.path.join(dataset_path, 'validation_set')

# %%
class SafeImageFolder(ImageFolder):
    def is_image_valid(self, path):
        """Check if the image at the given path is valid."""
        try:
            with Image.open(path) as img:
                img.verify()  # Verify that the image is valid
            return True
        except (UnidentifiedImageError, OSError):
            return False

    def __init__(self, root, csv_file=None, transform=None, target_transform=None):
        """
        Initialize SafeImageFolder with filtering of corrupted images and optional CSV-based labels.
        The class will only return images and labels (no bounding boxes).
        """
        super(SafeImageFolder, self).__init__(root, transform=transform, target_transform=target_transform)

        if csv_file:
            # Load the CSV file containing filename and class labels (no bounding boxes)
            df = pd.read_csv(csv_file)

            # Create a dictionary from the CSV for faster lookup
            self.trainset_to_label = df.set_index('filename')['class'].to_dict()

            # Filter out corrupted images and map them to class labels from the CSV file
            # Only include samples with valid class labels
            self.samples = [(path, self.get_label_from_filename(os.path.basename(path)))
                            for path, _ in self.samples
                            if self.is_image_valid(path) and self.get_label_from_filename(os.path.basename(path)) is not None]
        else:
            # No CSV file provided, just filter out corrupted images and return original labels
            self.samples = [(path, label) for path, label in self.samples if self.is_image_valid(path)]

    def get_label_from_filename(self, filename):
        """
        Retrieve the class label for a given filename from the CSV-based dictionary.
        Return None if the record does not exist or if the class label is missing.
        """
        return self.trainset_to_label.get(filename, None)

    def __getitem__(self, index):
        path, label = self.samples[index]
        sample = self.loader(path)

        # If the label is None, handle it (e.g., skip or raise an error)
        if label is None:
            raise ValueError(f"Invalid label for image {os.path.basename(path)}")

        if self.transform is not None:
            sample = self.transform(sample)

        if self.target_transform is not None:
            label = self.target_transform(label)

        # Return image and label (no bounding box)
        return sample, label

# %%
label_mapping = {
    'one': 0,    # Change from 1 to 0
    'two': 1,
    'three': 2,
    'four': 3,
    'five': 4
}

class ValidationImageFolder(ImageFolder):
    def __init__(self, root, transform=None):
        super().__init__(root, transform=transform)

    def __getitem__(self, index):
        path, _ = self.samples[index]  # Ignore labels here
        sample = self.loader(path)

        if self.transform:
            sample = self.transform(sample)

        # Extract the label from the filename
        filename = os.path.basename(path)
        label_str = filename.split('_')[0]  # Assuming labels are extracted as 'label_img.jpg'
        class_label = label_mapping.get(label_str, -1)  # Use -1 to indicate not found

        # Validate the class label
        if class_label == -1:
            raise ValueError(f"Label '{label_str}' not found in mapping. Filename: {filename}")

        return sample, class_label  # Return the image and its class label

# %%
train_dataset = SafeImageFolder(root=train_dir, csv_file='https://raw.githubusercontent.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset/refs/heads/master/Example_Datasets/Combined_Fingers_2000_400_400/training_set/silhouettes/all_labels.csv', transform=train_transform)
test_dataset = SafeImageFolder(root=test_dir, csv_file='https://raw.githubusercontent.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset/refs/heads/master/Example_Datasets/Combined_Fingers_2000_400_400/testing_set/silhouettes/all_labels.csv', transform=test_transform)
validation_dataset = ValidationImageFolder(root=validation_dir, transform=test_transform)

# Check dataset lengths
print(f"Total number of images in the training set: {len(train_dataset)}")
print(f"Total number of images in the test set: {len(test_dataset)}")
print(f"Total number of images in the validation set: {len(validation_dataset)}")
# Out:
# Total number of images in the training set: 2000
# Total number of images in the test set: 400
# Total number of images in the validation set: 400

# %% [markdown]
# Creating DataLoaders

# %%
def custom_collate_fn(batch):
    """
    Collate function for batching images and labels together.
    Expects a batch of (image, label) tuples and returns stacked images and a list of labels.
    This version adjusts labels to be zero-indexed.
    """
    # Unzip the batch into images and labels
    images, labels = zip(*batch)

    # Stack images into a tensor
    images = default_collate(images)  # Use default collate to handle batching of images

    # Adjust labels to be zero-indexed (assuming original labels are 1-based, i.e., 1 to 5)
    labels = [label - 1 for label in labels]  # Subtract 1 to shift to 0-based indexing

    # Convert labels to a tensor (if they're not already)
    labels = torch.tensor(labels, dtype=torch.int64)

    # Return the images and labels
    return images, labels

# %%
def validation_collate_fn(batch):
    """
    Collate function for batching images and labels together.
    Expects a batch of (image, label) tuples and returns stacked images and a list of labels.
    """
    # Unzip the batch into images and labels
    images, labels = zip(*batch)

    # Stack images into a tensor
    images = default_collate(images)  # Use default collate to handle batching of images

    # Convert labels to a tensor (if they're not already)
    labels = torch.tensor(labels, dtype=torch.int64)

    # Return the images and labels
    return images, labels

# %%
batch_size = 4

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True,collate_fn=custom_collate_fn)
valid_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True, collate_fn=validation_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn)

# %%
for batch_idx, (images, labels) in enumerate(train_loader):  # Assuming train_loader is your DataLoader
    # Print the shape of the images being passed to the model
    print(f"Batch {batch_idx + 1}:")
    print(f"Images shape: {images.shape}")  # Inspect the shape of images tensor
    print(f"Labels: {labels}")  # Print all labels
# Out:
# Batch 1:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 0])
# Batch 2:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 4])
# Batch 3:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 4, 3])
# Batch 4:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 4])
# Batch 5:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 2])
# Batch 6:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 2])
# Batch 7:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 1])
# Batch 8:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 1])
# Batch 9:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 4])
# Batch 10:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 1])
# Batch 11:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 4])
# Batch 12:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 3])
# Batch 13:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 0])
# Batch 14:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 0])
# Batch 15:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 0])
# Batch 16:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 0])
# Batch 17:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 0])
# Batch 18:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 3])
# Batch 19:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 2])
# Batch 20:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 2])
# Batch 21:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 4])
# Batch 22:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 4])
# Batch 23:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 2])
# Batch 24:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 3])
# Batch 25:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 0, 3])
# Batch 26:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 2])
# Batch 27:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 1])
# Batch 28:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 2])
# Batch 29:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 1, 1])
# Batch 30:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 4])
# Batch 31:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 3])
# Batch 32:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 0])
# Batch 33:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 3])
# Batch 34:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 3])
# Batch 35:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 4, 0])
# Batch 36:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 4])
# Batch 37:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 2])
# Batch 38:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 3])
# Batch 39:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 1])
# Batch 40:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 3])
# Batch 41:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 3])
# Batch 42:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 1])
# Batch 43:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 2])
# Batch 44:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 3])
# Batch 45:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 3])
# Batch 46:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 3, 3])
# Batch 47:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 3])
# Batch 48:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 0])
# Batch 49:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 3])
# Batch 50:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 0])
# Batch 51:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 2])
# Batch 52:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 3])
# Batch 53:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 2])
# Batch 54:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 0])
# Batch 55:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 1])
# Batch 56:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 3])
# Batch 57:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 2])
# Batch 58:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 0])
# Batch 59:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 1])
# Batch 60:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 1])
# Batch 61:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 0, 4])
# Batch 62:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 1])
# Batch 63:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 3])
# Batch 64:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 2])
# Batch 65:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 2])
# Batch 66:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 3])
# Batch 67:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 2])
# Batch 68:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 2])
# Batch 69:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 70:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 1])
# Batch 71:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 1])
# Batch 72:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 3])
# Batch 73:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 4])
# Batch 74:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 0])
# Batch 75:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 3, 4])
# Batch 76:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 4, 2])
# Batch 77:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 3])
# Batch 78:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 3])
# Batch 79:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 1])
# Batch 80:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 4])
# Batch 81:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 1])
# Batch 82:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 2])
# Batch 83:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 4])
# Batch 84:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 1])
# Batch 85:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 4])
# Batch 86:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 0])
# Batch 87:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 3])
# Batch 88:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 0])
# Batch 89:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 1])
# Batch 90:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 0])
# Batch 91:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 3])
# Batch 92:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 2])
# Batch 93:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 0])
# Batch 94:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 3])
# Batch 95:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 0])
# Batch 96:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 2])
# Batch 97:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 0])
# Batch 98:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 4])
# Batch 99:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 2])
# Batch 100:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 3])
# Batch 101:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 0])
# Batch 102:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 4])
# Batch 103:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 3])
# Batch 104:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 3, 3])
# Batch 105:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 0])
# Batch 106:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 3])
# Batch 107:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 3])
# Batch 108:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 1])
# Batch 109:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 4])
# Batch 110:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 3])
# Batch 111:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 1, 0])
# Batch 112:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 3])
# Batch 113:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 3])
# Batch 114:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 2])
# Batch 115:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 2])
# Batch 116:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 3])
# Batch 117:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 3])
# Batch 118:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 2])
# Batch 119:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 2])
# Batch 120:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 4])
# Batch 121:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 122:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 0])
# Batch 123:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 3, 4])
# Batch 124:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 3])
# Batch 125:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 3])
# Batch 126:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 2])
# Batch 127:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 4])
# Batch 128:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 0, 1])
# Batch 129:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 1])
# Batch 130:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 131:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 3])
# Batch 132:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 3])
# Batch 133:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 3])
# Batch 134:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 2])
# Batch 135:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 136:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 1])
# Batch 137:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 2])
# Batch 138:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 3])
# Batch 139:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 0])
# Batch 140:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 3, 4])
# Batch 141:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 1])
# Batch 142:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 3])
# Batch 143:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 0])
# Batch 144:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 0])
# Batch 145:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 146:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 2])
# Batch 147:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 4])
# Batch 148:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 0])
# Batch 149:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 1])
# Batch 150:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 0])
# Batch 151:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 1])
# Batch 152:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 153:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 2])
# Batch 154:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 1])
# Batch 155:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 0])
# Batch 156:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 2])
# Batch 157:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 1])
# Batch 158:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 2])
# Batch 159:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 0])
# Batch 160:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 0])
# Batch 161:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 3])
# Batch 162:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 3, 0])
# Batch 163:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 3])
# Batch 164:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 4, 3])
# Batch 165:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 1, 0])
# Batch 166:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 0])
# Batch 167:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 4])
# Batch 168:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 2])
# Batch 169:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 3])
# Batch 170:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 4, 0])
# Batch 171:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 4])
# Batch 172:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 4])
# Batch 173:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 1, 4])
# Batch 174:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 1])
# Batch 175:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 4])
# Batch 176:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 2])
# Batch 177:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 2])
# Batch 178:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 4])
# Batch 179:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 1])
# Batch 180:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 2])
# Batch 181:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 0])
# Batch 182:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 2])
# Batch 183:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 0])
# Batch 184:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 1])
# Batch 185:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 1])
# Batch 186:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 3])
# Batch 187:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 4, 1])
# Batch 188:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 4])
# Batch 189:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 2])
# Batch 190:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 2])
# Batch 191:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 3])
# Batch 192:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 0])
# Batch 193:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 3])
# Batch 194:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 3])
# Batch 195:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 1])
# Batch 196:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 0])
# Batch 197:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 1, 2])
# Batch 198:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 199:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 4])
# Batch 200:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 3])
# Batch 201:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 2])
# Batch 202:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 1])
# Batch 203:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 0])
# Batch 204:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 1])
# Batch 205:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 2])
# Batch 206:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 4])
# Batch 207:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 0])
# Batch 208:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 3])
# Batch 209:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 2])
# Batch 210:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 4])
# Batch 211:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 0])
# Batch 212:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 1])
# Batch 213:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 2])
# Batch 214:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 0])
# Batch 215:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 0])
# Batch 216:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 4])
# Batch 217:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 2])
# Batch 218:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 4])
# Batch 219:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 4])
# Batch 220:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 3])
# Batch 221:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 222:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 4])
# Batch 223:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 0])
# Batch 224:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 4])
# Batch 225:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 2])
# Batch 226:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 4])
# Batch 227:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 4])
# Batch 228:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 3])
# Batch 229:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 0])
# Batch 230:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 1])
# Batch 231:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 232:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 1])
# Batch 233:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 1])
# Batch 234:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 4, 3])
# Batch 235:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 2])
# Batch 236:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 1, 0])
# Batch 237:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 0])
# Batch 238:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 4])
# Batch 239:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 2])
# Batch 240:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 3])
# Batch 241:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 0])
# Batch 242:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 4])
# Batch 243:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 1])
# Batch 244:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 1])
# Batch 245:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 0])
# Batch 246:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 2])
# Batch 247:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 3])
# Batch 248:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 3])
# Batch 249:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 1])
# Batch 250:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 0])
# Batch 251:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 4])
# Batch 252:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 3])
# Batch 253:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 1])
# Batch 254:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 3])
# Batch 255:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 3])
# Batch 256:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 3])
# Batch 257:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 3, 2])
# Batch 258:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 259:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 1])
# Batch 260:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 261:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 1, 4])
# Batch 262:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 0])
# Batch 263:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 4])
# Batch 264:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 1])
# Batch 265:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 266:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 2])
# Batch 267:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 268:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 3])
# Batch 269:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 2])
# Batch 270:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 0])
# Batch 271:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 4])
# Batch 272:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 1])
# Batch 273:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 3])
# Batch 274:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 2])
# Batch 275:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 3])
# Batch 276:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 3])
# Batch 277:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 3])
# Batch 278:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 4])
# Batch 279:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 4])
# Batch 280:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 3])
# Batch 281:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 0])
# Batch 282:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 1])
# Batch 283:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 3])
# Batch 284:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 4, 0])
# Batch 285:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 0])
# Batch 286:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 4])
# Batch 287:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 4])
# Batch 288:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 0])
# Batch 289:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 4])
# Batch 290:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 3])
# Batch 291:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 1])
# Batch 292:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 4, 0])
# Batch 293:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 2])
# Batch 294:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 1])
# Batch 295:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 4])
# Batch 296:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 0])
# Batch 297:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 4])
# Batch 298:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 3])
# Batch 299:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 2])
# Batch 300:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 2])
# Batch 301:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 1])
# Batch 302:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 1])
# Batch 303:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 2])
# Batch 304:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 3])
# Batch 305:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 1])
# Batch 306:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 307:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 308:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 2])
# Batch 309:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 3])
# Batch 310:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 4])
# Batch 311:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 4])
# Batch 312:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 1])
# Batch 313:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 2])
# Batch 314:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 2, 2])
# Batch 315:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 1])
# Batch 316:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 0])
# Batch 317:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 4])
# Batch 318:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 2])
# Batch 319:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 4])
# Batch 320:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 1])
# Batch 321:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 4])
# Batch 322:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 4])
# Batch 323:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 324:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 3])
# Batch 325:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 0])
# Batch 326:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 0])
# Batch 327:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 2])
# Batch 328:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 3])
# Batch 329:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 4])
# Batch 330:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 0])
# Batch 331:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 1])
# Batch 332:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 4, 1])
# Batch 333:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 4])
# Batch 334:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 4])
# Batch 335:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 3])
# Batch 336:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 2])
# Batch 337:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 0, 4])
# Batch 338:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 2])
# Batch 339:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 340:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 0])
# Batch 341:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 4])
# Batch 342:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 2])
# Batch 343:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 4])
# Batch 344:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 3])
# Batch 345:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 4])
# Batch 346:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 2])
# Batch 347:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 3])
# Batch 348:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 1, 1])
# Batch 349:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 2])
# Batch 350:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 2])
# Batch 351:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 3])
# Batch 352:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 2])
# Batch 353:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 354:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 2])
# Batch 355:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 3])
# Batch 356:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 1])
# Batch 357:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 0])
# Batch 358:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 0])
# Batch 359:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 3])
# Batch 360:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 1])
# Batch 361:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 3])
# Batch 362:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 4, 3])
# Batch 363:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 2])
# Batch 364:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 1])
# Batch 365:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 0, 1])
# Batch 366:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 1])
# Batch 367:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 3])
# Batch 368:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 2])
# Batch 369:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 3])
# Batch 370:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 2])
# Batch 371:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 3])
# Batch 372:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 4])
# Batch 373:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 2])
# Batch 374:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 4])
# Batch 375:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 2])
# Batch 376:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 0])
# Batch 377:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 3])
# Batch 378:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 0])
# Batch 379:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 4])
# Batch 380:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 4])
# Batch 381:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 1])
# Batch 382:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 2, 3])
# Batch 383:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 1])
# Batch 384:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 3])
# Batch 385:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 2])
# Batch 386:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 1])
# Batch 387:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 1])
# Batch 388:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 4])
# Batch 389:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 2, 0])
# Batch 390:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 0])
# Batch 391:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 3])
# Batch 392:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 4])
# Batch 393:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 2])
# Batch 394:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 2])
# Batch 395:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 4])
# Batch 396:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 2])
# Batch 397:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 1])
# Batch 398:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 4])
# Batch 399:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 3])
# Batch 400:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 1])
# Batch 401:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 2])
# Batch 402:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 1, 1])
# Batch 403:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 0])
# Batch 404:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 1])
# Batch 405:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 406:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 407:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 2])
# Batch 408:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 1])
# Batch 409:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 410:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 3])
# Batch 411:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 1])
# Batch 412:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 3])
# Batch 413:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 2])
# Batch 414:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 1])
# Batch 415:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 4])
# Batch 416:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 1])
# Batch 417:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 0])
# Batch 418:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 1])
# Batch 419:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 1])
# Batch 420:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 2])
# Batch 421:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 0])
# Batch 422:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 2])
# Batch 423:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 4])
# Batch 424:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 4])
# Batch 425:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 1])
# Batch 426:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 3])
# Batch 427:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 2])
# Batch 428:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 2])
# Batch 429:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 3])
# Batch 430:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 431:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 2])
# Batch 432:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 0])
# Batch 433:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 3])
# Batch 434:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 0])
# Batch 435:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 1])
# Batch 436:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 4])
# Batch 437:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 2, 0])
# Batch 438:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 0])
# Batch 439:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 1])
# Batch 440:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 2, 0])
# Batch 441:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 2])
# Batch 442:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 2])
# Batch 443:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 1])
# Batch 444:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 3, 3])
# Batch 445:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 1])
# Batch 446:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 4])
# Batch 447:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 1])
# Batch 448:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 2])
# Batch 449:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 2])
# Batch 450:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 2])
# Batch 451:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 1])
# Batch 452:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 0])
# Batch 453:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 1])
# Batch 454:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 2])
# Batch 455:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 2])
# Batch 456:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 3])
# Batch 457:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 4])
# Batch 458:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 1])
# Batch 459:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 1])
# Batch 460:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 2])
# Batch 461:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 2])
# Batch 462:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 0])
# Batch 463:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 0])
# Batch 464:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 2])
# Batch 465:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 1])
# Batch 466:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 1])
# Batch 467:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 0])
# Batch 468:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 3])
# Batch 469:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 0, 2])
# Batch 470:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 4])
# Batch 471:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 3])
# Batch 472:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 2])
# Batch 473:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 474:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 4])
# Batch 475:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 4])
# Batch 476:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 1])
# Batch 477:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 3])
# Batch 478:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 2])
# Batch 479:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 4])
# Batch 480:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 1])
# Batch 481:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 4])
# Batch 482:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 2])
# Batch 483:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 484:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 1])
# Batch 485:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 4])
# Batch 486:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 3])
# Batch 487:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 4])
# Batch 488:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 1])
# Batch 489:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 1])
# Batch 490:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 1])
# Batch 491:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 2])
# Batch 492:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 0])
# Batch 493:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 4])
# Batch 494:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 2])
# Batch 495:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 1])
# Batch 496:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 0])
# Batch 497:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 3])
# Batch 498:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 2])
# Batch 499:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 0])
# Batch 500:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 0])

# %% [markdown]
# Sample Visualization

# %%
trainset_to_label = {0: '1', 1: '2', 2: '3', 3: '4', 4: '5'}

def imshow(inp, title=None):
    """Display image for Tensor."""

    plt.figure(figsize=(12, 8))
    inp = inp.numpy().transpose((1, 2, 0))  # Convert tensor to numpy and adjust dimensions for plt.imshow
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.axis('off')  # Turn off axis
    plt.pause(0.001)  # Pause to allow display update

# Get batch of images and labels from your DataLoader
train_loader_for_vis = DataLoader(train_dataset, batch_size=7, shuffle=True, num_workers=0, collate_fn=custom_collate_fn)
inputs, labels = next(iter(train_loader_for_vis))  # Assume the second item in batch is labels

# Create a grid of the images
out = torchvision.utils.make_grid(inputs)

# Convert labels to readable titles
titles = [trainset_to_label.get(label.item(), 'Unknown') for label in labels]  # Use integer labels directly

# Visualize the grid of images with the mapped class names as titles
imshow(out, title=', '.join(titles))

# %% [markdown]
# Model Building

# %%
from torchvision import models
from torchvision.models import resnet50
import time
# !pip install torchsummary
from torchsummary import summary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
model = models.efficientnet_b7(pretrained=True)

num_classes = 5
in_features = model.classifier[1].in_features  # Get the number of input features to the final layer
model.classifier[1] = nn.Linear(in_features, num_classes)  # Replace the layer

# Transfer the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Print the modified model (optional)
print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B7_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B7_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b7_lukemelas-c5b4e57e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b7_lukemelas-c5b4e57e.pth
# 100%|██████████| 255M/255M [00:16<00:00, 16.6MB/s]
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0036363636363636364, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.007272727272727273, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.01090909090909091, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.014545454545454545, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.01818181818181818, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02181818181818182, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025454545454545455, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02909090909090909, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03272727272727273, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03636363636363636, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04363636363636364, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04727272727272727, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05090909090909091, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05454545454545454, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05818181818181818, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06181818181818183, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06545454545454546, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06909090909090909, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07272727272727272, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07636363636363637, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08363636363636365, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08727272727272728, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09090909090909091, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09454545454545454, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09818181818181819, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10181818181818182, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10545454545454547, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10909090909090909, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11272727272727273, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11636363636363636, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12363636363636366, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12727272727272726, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13090909090909092, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13454545454545455, mode=row)
# ...
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15272727272727274, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15636363636363634, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16363636363636364, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1672727272727273, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17090909090909093, mode=row)
#       )
#       (10): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17454545454545456, mode=row)
#       )
#       (11): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1781818181818182, mode=row)
#       )
#       (12): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18181818181818182, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18545454545454548, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1890909090909091, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19272727272727275, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19636363636363638, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(640, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2560, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=2560, out_features=5, bias=True)
#   )
# )

# %%
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           1,728
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#
#      BatchNorm2d-815            [-1, 640, 7, 7]           1,280
#           MBConv-816            [-1, 640, 7, 7]               0
#           Conv2d-817           [-1, 3840, 7, 7]       2,457,600
#      BatchNorm2d-818           [-1, 3840, 7, 7]           7,680
#             SiLU-819           [-1, 3840, 7, 7]               0
#           Conv2d-820           [-1, 3840, 7, 7]          34,560
#      BatchNorm2d-821           [-1, 3840, 7, 7]           7,680
#             SiLU-822           [-1, 3840, 7, 7]               0
# AdaptiveAvgPool2d-823           [-1, 3840, 1, 1]               0
#           Conv2d-824            [-1, 160, 1, 1]         614,560
#             SiLU-825            [-1, 160, 1, 1]               0
#           Conv2d-826           [-1, 3840, 1, 1]         618,240
#          Sigmoid-827           [-1, 3840, 1, 1]               0
# SqueezeExcitation-828           [-1, 3840, 7, 7]               0
#           Conv2d-829            [-1, 640, 7, 7]       2,457,600
#      BatchNorm2d-830            [-1, 640, 7, 7]           1,280
#  StochasticDepth-831            [-1, 640, 7, 7]               0
#           MBConv-832            [-1, 640, 7, 7]               0
#           Conv2d-833           [-1, 3840, 7, 7]       2,457,600
#      BatchNorm2d-834           [-1, 3840, 7, 7]           7,680
#             SiLU-835           [-1, 3840, 7, 7]               0
#           Conv2d-836           [-1, 3840, 7, 7]          34,560
#      BatchNorm2d-837           [-1, 3840, 7, 7]           7,680
#             SiLU-838           [-1, 3840, 7, 7]               0
# AdaptiveAvgPool2d-839           [-1, 3840, 1, 1]               0
#           Conv2d-840            [-1, 160, 1, 1]         614,560
#             SiLU-841            [-1, 160, 1, 1]               0
#           Conv2d-842           [-1, 3840, 1, 1]         618,240
#          Sigmoid-843           [-1, 3840, 1, 1]               0
# SqueezeExcitation-844           [-1, 3840, 7, 7]               0
#           Conv2d-845            [-1, 640, 7, 7]       2,457,600
#      BatchNorm2d-846            [-1, 640, 7, 7]           1,280
#  StochasticDepth-847            [-1, 640, 7, 7]               0
#           MBConv-848            [-1, 640, 7, 7]               0
#           Conv2d-849           [-1, 3840, 7, 7]       2,457,600
#      BatchNorm2d-850           [-1, 3840, 7, 7]           7,680
#             SiLU-851           [-1, 3840, 7, 7]               0
#           Conv2d-852           [-1, 3840, 7, 7]          34,560
#      BatchNorm2d-853           [-1, 3840, 7, 7]           7,680
#             SiLU-854           [-1, 3840, 7, 7]               0
# AdaptiveAvgPool2d-855           [-1, 3840, 1, 1]               0
#           Conv2d-856            [-1, 160, 1, 1]         614,560
#             SiLU-857            [-1, 160, 1, 1]               0
#           Conv2d-858           [-1, 3840, 1, 1]         618,240
#          Sigmoid-859           [-1, 3840, 1, 1]               0
# SqueezeExcitation-860           [-1, 3840, 7, 7]               0
#           Conv2d-861            [-1, 640, 7, 7]       2,457,600
#      BatchNorm2d-862            [-1, 640, 7, 7]           1,280
#  StochasticDepth-863            [-1, 640, 7, 7]               0
#           MBConv-864            [-1, 640, 7, 7]               0
#           Conv2d-865           [-1, 2560, 7, 7]       1,638,400
#      BatchNorm2d-866           [-1, 2560, 7, 7]           5,120
#             SiLU-867           [-1, 2560, 7, 7]               0
# AdaptiveAvgPool2d-868           [-1, 2560, 1, 1]               0
#          Dropout-869                 [-1, 2560]               0
#           Linear-870                    [-1, 5]          12,805
# ================================================================
# Total params: 63,799,765
# Trainable params: 63,799,765
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 1073.57
# Params size (MB): 243.38
# Estimated Total Size (MB): 1317.52
# ----------------------------------------------------------------

# %% [markdown]
# Hyperparameters - Loss Function and Optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0003)

# %% [markdown]
# Training and Validation Loop

# %%
# The number of training epochs.
n_epochs = 50

# These are used to record information
best_valid_acc = 0
train_loss_epochs = []
train_acc_epochs = []
valid_loss_epochs = []
valid_acc_epochs = []

for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []

    # Iterate the training set by batches.
    for batch in tqdm(train_loader):

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        imgs = imgs.to(device)
        labels = labels.to(device)

        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs)

        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = criterion(logits, labels)

        # Compute the gradients for parameters.
        loss.backward()

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc.item())

    # The average loss and accuracy of the training set is the average of the recorded values.
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)
    train_loss_epochs.append(train_loss)
    train_acc_epochs.append(train_acc)

    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in tqdm(valid_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        imgs = imgs.to(device)
        labels = labels.to(device)

        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
          logits = model(imgs)

        # We can still compute the loss (but not the gradient).
        loss = criterion(logits, labels)

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc.item())

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)
    valid_loss_epochs.append(valid_loss)
    valid_acc_epochs.append(valid_acc)

    # save the best model
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc
        torch.save(model.state_dict(), 'best_model.pth')

    # Print the information.
    print(f"[Epoch: {epoch + 1:03d}/{n_epochs:03d}] Train: loss={train_loss:.5f}, acc={train_acc:.5f} | Valid: loss={valid_loss:.5f}, acc={valid_acc:.5f}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 001/050] Train: loss=1.61136, acc=0.21500 | Valid: loss=1.61367, acc=0.23000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 002/050] Train: loss=1.61295, acc=0.21100 | Valid: loss=1.61081, acc=0.23500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epo
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 035/050] Train: loss=1.42857, acc=0.40350 | Valid: loss=1.40410, acc=0.45250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 036/050] Train: loss=1.41253, acc=0.41750 | Valid: loss=1.39106, acc=0.46750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 037/050] Train: loss=1.40726, acc=0.41000 | Valid: loss=1.38057, acc=0.46000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 038/050] Train: loss=1.39230, acc=0.42550 | Valid: loss=1.37029, acc=0.45250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 039/050] Train: loss=1.37821, acc=0.42850 | Valid: loss=1.35784, acc=0.46750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 040/050] Train: loss=1.36926, acc=0.43650 | Valid: loss=1.34497, acc=0.45500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 041/050] Train: loss=1.35598, acc=0.43650 | Valid: loss=1.33558, acc=0.46000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 042/050] Train: loss=1.35215, acc=0.43750 | Valid: loss=1.31908, acc=0.46500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 043/050] Train: loss=1.33748, acc=0.44750 | Valid: loss=1.31400, acc=0.47000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 044/050] Train: loss=1.32966, acc=0.43800 | Valid: loss=1.29874, acc=0.47500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 045/050] Train: loss=1.33130, acc=0.44250 | Valid: loss=1.28963, acc=0.47250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 046/050] Train: loss=1.32149, acc=0.44400 | Valid: loss=1.28422, acc=0.49250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 047/050] Train: loss=1.30700, acc=0.45150 | Valid: loss=1.27716, acc=0.49250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 048/050] Train: loss=1.29744, acc=0.45300 | Valid: loss=1.26786, acc=0.50250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 049/050] Train: loss=1.28091, acc=0.46350 | Valid: loss=1.25619, acc=0.50000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 050/050] Train: loss=1.27153, acc=0.46700 | Valid: loss=1.23867, acc=0.50000

# %% [markdown]
# Plotting Loss Curves

# %%
# Plotting the loss curves
plt.figure()
plt.plot(train_loss_epochs, label='Train Loss')
plt.plot(valid_loss_epochs, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# Plotting the accuracy curves
plt.figure()
plt.plot(train_acc_epochs, label='Train Accuracy')
plt.plot(valid_acc_epochs, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Testing Loop

# %%
# load best model weights
model.load_state_dict(torch.load('best_model.pth'))

# Make sure the model is in eval mode.
# Some modules like Dropout or BatchNorm affect if the model is in training mode.
model.eval()

test_accs = []

# Iterate the testing set by batches.
for batch in tqdm(test_loader):
    # A batch consists of image data and corresponding labels.
    imgs, labels = batch
    imgs = imgs.to(device)
    labels = labels.to(device)

    # We don't need gradient in test
    # Using torch.no_grad() accelerates the forward process.
    with torch.no_grad():
      logits = model(imgs)

    # We can still compute the loss (but not the gradient).
    loss = criterion(logits, labels)

    # Compute the accuracy for current batch.
    acc = (logits.argmax(dim=-1) == labels).float().mean()

    # Record accuracy.
    test_accs.append(acc)

# The average accuracy for entire test set is the average of the recorded values.
test_acc = sum(test_accs) / len(test_accs)
print(f'Test accuracy {test_acc}')
# Out:
# <ipython-input-22-7201ed175c95>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
#   0%|          | 0/100 [00:00<?, ?it/s]
# Test accuracy 0.48499998450279236

# %% [markdown]
# Evaluation Metrics and Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
model.eval()
all_labels = []
all_preds = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)

# %%
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Accuracy: 0.485
# Precision: 0.5284091982020463
# Recall: 0.485

# %%
class_names = ['one', 'two', 'three', 'four', 'five']

# Initialize lists to hold all predictions and ground-truth labels
all_preds = []
all_labels = []

# Ensure model is in evaluation mode
model.eval()

# Disable gradient calculation for faster computations
with torch.no_grad():
    for inputs, labels in test_loader:  # Use your test DataLoader here
        inputs = inputs.to(device)  # Move inputs to the correct device (CPU/GPU)
        labels = labels.to(device)  # Move labels to the correct device

        # Forward pass: get predictions
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)  # Get the class with the highest score

        # Collect predictions and labels
        all_preds.append(preds.to(device))  # Keep predictions on the GPU
        all_labels.append(labels.to(device))  # Keep labels on the GPU

# Convert lists to tensors, then move to the correct device
all_preds = torch.cat(all_preds).to(device)  # Concatenate and keep on GPU
all_labels = torch.cat(all_labels).to(device)  # Concatenate and keep on GPU

# Compute confusion matrix (move to CPU for sklearn compatibility)
cm = confusion_matrix(all_labels.cpu().numpy(), all_preds.cpu().numpy())

# Display the confusion matrix using sklearn's ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)

plt.title('Confusion Matrix (Test Set)')
plt.show()

# %% [markdown]
# Measuring Time and Memory Usage

# %%
def measure_time_and_memory(model, data_loader, criterion, optimizer=None, device='cuda'):
    """
    Measure the average time and memory usage for training or validation/testing.
    If optimizer is provided, it's for training; otherwise, it's for validation/testing.
    """
    model.to(device)
    total_time = 0.0
    total_memory = 0.0
    total_batches = 0

    # Ensure model is in training mode if optimizer is provided
    model.train() if optimizer else model.eval()

    # Disable gradient calculation for validation and testing
    with torch.no_grad() if not optimizer else torch.enable_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            start_time = time.time()  # Start time measurement

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            if optimizer:
                optimizer.zero_grad()
                loss.backward()  # Only needed during training
                optimizer.step()  # Update weights

            end_time = time.time()  # End time measurement

            # Measure memory usage
            memory_usage = torch.cuda.memory_allocated(device) / (1024 * 1024)  # in MB

            total_time += (end_time - start_time)
            total_memory += memory_usage
            total_batches += 1

    average_time = total_time / total_batches if total_batches > 0 else 0
    average_memory = total_memory / total_batches if total_batches > 0 else 0

    return average_time, average_memory


device = 'cuda' if torch.cuda.is_available() else 'cpu'  # Set device to CUDA or CPU based on availability
train_average_time, train_average_memory = measure_time_and_memory(model, train_loader, criterion, optimizer, device)
val_average_time, val_average_memory = measure_time_and_memory(model, valid_loader, criterion, device=device)
test_average_time, test_average_memory = measure_time_and_memory(model, test_loader, criterion, device=device)

print(f"Average Training Time: {train_average_time:.4f} seconds, Average Memory Usage: {train_average_memory:.2f} MB")
print(f"Average Validation Time: {val_average_time:.4f} seconds, Average Memory Usage: {val_average_memory:.2f} MB")
print(f"Average Testing Time: {test_average_time:.4f} seconds, Average Memory Usage: {test_average_memory:.2f} MB")
# Out:
# Average Training Time: 0.1096 seconds, Average Memory Usage: 540.61 MB
# Average Validation Time: 0.0325 seconds, Average Memory Usage: 541.21 MB
# Average Testing Time: 0.0306 seconds, Average Memory Usage: 541.21 MB
