# %% [markdown]
# Import Necessary Packages

# %%
import pandas as pd
import numpy as np
from PIL import Image
from PIL import UnidentifiedImageError
import os

import torch
import torch.nn as nn
from torch.utils.data import random_split
from torch.utils.data import Dataset, DataLoader, Subset
from torch.utils.data.dataloader import default_collate

import torchvision
from torchvision import datasets, transforms
from torchvision.datasets import DatasetFolder
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# This is for the progress bar
from tqdm.auto import tqdm
# This is for ploting
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset.git
# Out:
# Cloning into 'Human-Robot_Finger-Counting_Dataset'...
# remote: Enumerating objects: 12476, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 12476 (delta 8), reused 5 (delta 1), pack-reused 12454 (from 1)
# Receiving objects: 100% (12476/12476), 474.51 MiB | 22.23 MiB/s, done.
# Resolving deltas: 100% (2435/2435), done.
# Updating files: 100% (28820/28820), done.

# %%
# !ls /content/Human-Robot_Finger-Counting_Dataset
# Out:
# Backgrounds  Example_Datasets  LICENCE	Raw_Images  README.md  Toolbox

# %%
dataset_path = 'Human-Robot_Finger-Counting_Dataset/Example_Datasets/Combined_Fingers_2000_400_400'

# %%
dataset = datasets.ImageFolder(root=dataset_path)
len(dataset)
# Out:
# 5200

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=30),
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
train_dir = os.path.join(dataset_path, 'training_set')
test_dir = os.path.join(dataset_path, 'testing_set')
validation_dir = os.path.join(dataset_path, 'validation_set')

# %%
class SafeImageFolder(ImageFolder):
    def is_image_valid(self, path):
        """Check if the image at the given path is valid."""
        try:
            with Image.open(path) as img:
                img.verify()  # Verify that the image is valid
            return True
        except (UnidentifiedImageError, OSError):
            return False

    def __init__(self, root, csv_file=None, transform=None, target_transform=None):
        """
        Initialize SafeImageFolder with filtering of corrupted images and optional CSV-based labels.
        The class will only return images and labels (no bounding boxes).
        """
        super(SafeImageFolder, self).__init__(root, transform=transform, target_transform=target_transform)

        if csv_file:
            # Load the CSV file containing filename and class labels (no bounding boxes)
            df = pd.read_csv(csv_file)

            # Create a dictionary from the CSV for faster lookup
            self.trainset_to_label = df.set_index('filename')['class'].to_dict()

            # Filter out corrupted images and map them to class labels from the CSV file
            # Only include samples with valid class labels
            self.samples = [(path, self.get_label_from_filename(os.path.basename(path)))
                            for path, _ in self.samples
                            if self.is_image_valid(path) and self.get_label_from_filename(os.path.basename(path)) is not None]
        else:
            # No CSV file provided, just filter out corrupted images and return original labels
            self.samples = [(path, label) for path, label in self.samples if self.is_image_valid(path)]

    def get_label_from_filename(self, filename):
        """
        Retrieve the class label for a given filename from the CSV-based dictionary.
        Return None if the record does not exist or if the class label is missing.
        """
        return self.trainset_to_label.get(filename, None)

    def __getitem__(self, index):
        path, label = self.samples[index]
        sample = self.loader(path)

        # If the label is None, handle it (e.g., skip or raise an error)
        if label is None:
            raise ValueError(f"Invalid label for image {os.path.basename(path)}")

        if self.transform is not None:
            sample = self.transform(sample)

        if self.target_transform is not None:
            label = self.target_transform(label)

        # Return image and label (no bounding box)
        return sample, label

# %%
label_mapping = {
    'one': 0,    # Change from 1 to 0
    'two': 1,
    'three': 2,
    'four': 3,
    'five': 4
}

class ValidationImageFolder(ImageFolder):
    def __init__(self, root, transform=None):
        super().__init__(root, transform=transform)

    def __getitem__(self, index):
        path, _ = self.samples[index]  # Ignore labels here
        sample = self.loader(path)

        if self.transform:
            sample = self.transform(sample)

        # Extract the label from the filename
        filename = os.path.basename(path)
        label_str = filename.split('_')[0]  # Assuming labels are extracted as 'label_img.jpg'
        class_label = label_mapping.get(label_str, -1)  # Use -1 to indicate not found

        # Validate the class label
        if class_label == -1:
            raise ValueError(f"Label '{label_str}' not found in mapping. Filename: {filename}")

        return sample, class_label  # Return the image and its class label

# %%
train_dataset = SafeImageFolder(root=train_dir, csv_file='https://raw.githubusercontent.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset/refs/heads/master/Example_Datasets/Combined_Fingers_2000_400_400/training_set/silhouettes/all_labels.csv', transform=train_transform)
test_dataset = SafeImageFolder(root=test_dir, csv_file='https://raw.githubusercontent.com/EPSRC-NUMBERS/Human-Robot_Finger-Counting_Dataset/refs/heads/master/Example_Datasets/Combined_Fingers_2000_400_400/testing_set/silhouettes/all_labels.csv', transform=test_transform)
validation_dataset = ValidationImageFolder(root=validation_dir, transform=test_transform)

# Check dataset lengths
print(f"Total number of images in the training set: {len(train_dataset)}")
print(f"Total number of images in the test set: {len(test_dataset)}")
print(f"Total number of images in the validation set: {len(validation_dataset)}")
# Out:
# Total number of images in the training set: 2000
# Total number of images in the test set: 400
# Total number of images in the validation set: 400

# %%
def custom_collate_fn(batch):
    """
    Collate function for batching images and labels together.
    Expects a batch of (image, label) tuples and returns stacked images and a list of labels.
    This version adjusts labels to be zero-indexed.
    """
    # Unzip the batch into images and labels
    images, labels = zip(*batch)

    # Stack images into a tensor
    images = default_collate(images)  # Use default collate to handle batching of images

    # Adjust labels to be zero-indexed (assuming original labels are 1-based, i.e., 1 to 5)
    labels = [label - 1 for label in labels]  # Subtract 1 to shift to 0-based indexing

    # Convert labels to a tensor (if they're not already)
    labels = torch.tensor(labels, dtype=torch.int64)

    # Return the images and labels
    return images, labels

# %%
def validation_collate_fn(batch):
    """
    Collate function for batching images and labels together.
    Expects a batch of (image, label) tuples and returns stacked images and a list of labels.
    """
    # Unzip the batch into images and labels
    images, labels = zip(*batch)

    # Stack images into a tensor
    images = default_collate(images)  # Use default collate to handle batching of images

    # Convert labels to a tensor (if they're not already)
    labels = torch.tensor(labels, dtype=torch.int64)

    # Return the images and labels
    return images, labels

# %%
batch_size = 4

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True,collate_fn=custom_collate_fn)
valid_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True, collate_fn=validation_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn)

# %%
for batch_idx, (images, labels) in enumerate(train_loader):  # Assuming train_loader is your DataLoader
    # Print the shape of the images being passed to the model
    print(f"Batch {batch_idx + 1}:")
    print(f"Images shape: {images.shape}")  # Inspect the shape of images tensor
    print(f"Labels: {labels}")  # Print all labels
# Out:
# Batch 1:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 0])
# Batch 2:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 2])
# Batch 3:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 1])
# Batch 4:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 3])
# Batch 5:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 4])
# Batch 6:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 7:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 4])
# Batch 8:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 3])
# Batch 9:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 3])
# Batch 10:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 1])
# Batch 11:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 1])
# Batch 12:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 3, 2])
# Batch 13:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 0])
# Batch 14:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 1])
# Batch 15:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 0])
# Batch 16:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 3])
# Batch 17:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 0])
# Batch 18:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 1])
# Batch 19:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 4])
# Batch 20:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 0])
# Batch 21:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 22:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 23:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 3])
# Batch 24:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 4])
# Batch 25:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 3])
# Batch 26:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 1])
# Batch 27:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 0])
# Batch 28:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 4])
# Batch 29:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 0])
# Batch 30:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 2])
# Batch 31:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 3])
# Batch 32:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 3])
# Batch 33:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 2])
# Batch 34:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 3])
# Batch 35:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 0])
# Batch 36:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 2])
# Batch 37:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 4])
# Batch 38:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 0])
# Batch 39:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 4])
# Batch 40:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 4])
# Batch 41:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 2])
# Batch 42:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 4])
# Batch 43:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 4])
# Batch 44:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 1])
# Batch 45:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 4])
# Batch 46:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 3])
# Batch 47:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 0])
# Batch 48:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 2])
# Batch 49:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 4])
# Batch 50:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 4])
# Batch 51:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 3, 0])
# Batch 52:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 4])
# Batch 53:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 3])
# Batch 54:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 4])
# Batch 55:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 56:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 4])
# Batch 57:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 4])
# Batch 58:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 3])
# Batch 59:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 2])
# Batch 60:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 2])
# Batch 61:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 1, 1])
# Batch 62:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 4])
# Batch 63:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 4])
# Batch 64:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 4, 0])
# Batch 65:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 4])
# Batch 66:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 2])
# Batch 67:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 4])
# Batch 68:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 0])
# Batch 69:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 2])
# Batch 70:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 4])
# Batch 71:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 4, 0])
# Batch 72:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 1])
# Batch 73:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 1])
# Batch 74:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 1])
# Batch 75:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 1])
# Batch 76:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 3])
# Batch 77:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 78:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 3, 1])
# Batch 79:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 0])
# Batch 80:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 2])
# Batch 81:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 3])
# Batch 82:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 2])
# Batch 83:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 2])
# Batch 84:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 3])
# Batch 85:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 2])
# Batch 86:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 3])
# Batch 87:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 2])
# Batch 88:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 1])
# Batch 89:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 1])
# Batch 90:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 4])
# Batch 91:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 0])
# Batch 92:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 1])
# Batch 93:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 1])
# Batch 94:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 1])
# Batch 95:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 3])
# Batch 96:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 2, 2])
# Batch 97:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 0])
# Batch 98:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 4])
# Batch 99:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 4, 1])
# Batch 100:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 2])
# Batch 101:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 3])
# Batch 102:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 4, 0])
# Batch 103:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 3])
# Batch 104:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 1])
# Batch 105:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 2])
# Batch 106:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 0])
# Batch 107:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 1])
# Batch 108:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 0])
# Batch 109:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 1, 3])
# Batch 110:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 3])
# Batch 111:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 0])
# Batch 112:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 2])
# Batch 113:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 114:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 3])
# Batch 115:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 4])
# Batch 116:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 2])
# Batch 117:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 1])
# Batch 118:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 0])
# Batch 119:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 1])
# Batch 120:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 2])
# Batch 121:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 0])
# Batch 122:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 3])
# Batch 123:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 1])
# Batch 124:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 3])
# Batch 125:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 2, 4])
# Batch 126:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 4, 2])
# Batch 127:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 1])
# Batch 128:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 4])
# Batch 129:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 3])
# Batch 130:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 131:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 3])
# Batch 132:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 2])
# Batch 133:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 4])
# Batch 134:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 3])
# Batch 135:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 1])
# Batch 136:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 2])
# Batch 137:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 1])
# Batch 138:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 4])
# Batch 139:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 1])
# Batch 140:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 2, 0])
# Batch 141:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 0, 4])
# Batch 142:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 3])
# Batch 143:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 4])
# Batch 144:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 145:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 2])
# Batch 146:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 4])
# Batch 147:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 3])
# Batch 148:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 0])
# Batch 149:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 3])
# Batch 150:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 4])
# Batch 151:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 0])
# Batch 152:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 0])
# Batch 153:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 4])
# Batch 154:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 155:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 2])
# Batch 156:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 4])
# Batch 157:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 0])
# Batch 158:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 3])
# Batch 159:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 3])
# Batch 160:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 1])
# Batch 161:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 3])
# Batch 162:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 0])
# Batch 163:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 3])
# Batch 164:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 2])
# Batch 165:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 1, 3])
# Batch 166:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 167:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 168:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 2])
# Batch 169:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 3])
# Batch 170:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 171:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 1])
# Batch 172:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 4])
# Batch 173:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 4])
# Batch 174:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 0])
# Batch 175:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 1])
# Batch 176:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 0, 2])
# Batch 177:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 0, 0])
# Batch 178:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 2])
# Batch 179:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 4])
# Batch 180:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 2])
# Batch 181:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 0, 4])
# Batch 182:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 4])
# Batch 183:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 3])
# Batch 184:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 4, 1])
# Batch 185:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 0])
# Batch 186:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 0])
# Batch 187:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 2])
# Batch 188:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 4])
# Batch 189:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 1])
# Batch 190:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 3])
# Batch 191:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 3, 0])
# Batch 192:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 4])
# Batch 193:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 0])
# Batch 194:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 2])
# Batch 195:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 2])
# Batch 196:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 1])
# Batch 197:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 3])
# Batch 198:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 2, 0])
# Batch 199:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 3])
# Batch 200:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 1])
# Batch 201:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 1])
# Batch 202:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 1])
# Batch 203:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 3])
# Batch 204:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 4])
# Batch 205:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 3])
# Batch 206:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 4])
# Batch 207:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 2])
# Batch 208:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 3])
# Batch 209:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 3, 2])
# Batch 210:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 2])
# Batch 211:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 3])
# Batch 212:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 1])
# Batch 213:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 0, 2])
# Batch 214:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 3])
# Batch 215:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 3])
# Batch 216:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 0])
# Batch 217:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 2])
# Batch 218:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 3])
# Batch 219:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 4])
# Batch 220:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 4, 2])
# Batch 221:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 0])
# Batch 222:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 0])
# Batch 223:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 0])
# Batch 224:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 2])
# Batch 225:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 2])
# Batch 226:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 0])
# Batch 227:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 2])
# Batch 228:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 1])
# Batch 229:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 3])
# Batch 230:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 4])
# Batch 231:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 1])
# Batch 232:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 0])
# Batch 233:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 0])
# Batch 234:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 1])
# Batch 235:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 2])
# Batch 236:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 4, 4])
# Batch 237:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 0])
# Batch 238:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 4])
# Batch 239:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 1])
# Batch 240:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 3])
# Batch 241:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 3])
# Batch 242:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 0])
# Batch 243:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 4])
# Batch 244:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 2])
# Batch 245:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 0])
# Batch 246:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 3])
# Batch 247:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 4])
# Batch 248:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 1])
# Batch 249:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 3])
# Batch 250:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 4])
# Batch 251:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 4])
# Batch 252:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 0])
# Batch 253:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 3, 1])
# Batch 254:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 255:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 0])
# Batch 256:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 0])
# Batch 257:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 2])
# Batch 258:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 0])
# Batch 259:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 2])
# Batch 260:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 2])
# Batch 261:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 1])
# Batch 262:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 2])
# Batch 263:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 3, 4])
# Batch 264:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 4])
# Batch 265:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 3])
# Batch 266:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 0])
# Batch 267:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 3, 3])
# Batch 268:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 4])
# Batch 269:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 270:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 1, 2])
# Batch 271:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 4])
# Batch 272:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 2])
# Batch 273:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 1])
# Batch 274:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 0, 1])
# Batch 275:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 0])
# Batch 276:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 2])
# Batch 277:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 3])
# Batch 278:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 2])
# Batch 279:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 2, 4])
# Batch 280:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 3])
# Batch 281:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 0, 1])
# Batch 282:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 0])
# Batch 283:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 4])
# Batch 284:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 3, 2])
# Batch 285:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 1])
# Batch 286:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 0])
# Batch 287:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 4])
# Batch 288:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 2])
# Batch 289:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 2, 3])
# Batch 290:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 4])
# Batch 291:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 4])
# Batch 292:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 3])
# Batch 293:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 3])
# Batch 294:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 0, 3])
# Batch 295:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 2, 2])
# Batch 296:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 1])
# Batch 297:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 3])
# Batch 298:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 4, 0])
# Batch 299:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 4])
# Batch 300:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 4])
# Batch 301:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 1])
# Batch 302:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 3])
# Batch 303:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 0])
# Batch 304:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 4])
# Batch 305:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 306:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 4])
# Batch 307:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 3])
# Batch 308:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 3, 4])
# Batch 309:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 3, 2])
# Batch 310:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 0, 0])
# Batch 311:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 3])
# Batch 312:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 2])
# Batch 313:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 4])
# Batch 314:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 315:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 1, 3])
# Batch 316:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 1, 3])
# Batch 317:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 3, 3])
# Batch 318:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 3])
# Batch 319:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 3])
# Batch 320:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 4])
# Batch 321:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 2, 1])
# Batch 322:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 0, 2])
# Batch 323:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 4])
# Batch 324:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 325:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 0])
# Batch 326:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 0])
# Batch 327:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 2])
# Batch 328:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 3, 0])
# Batch 329:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 2])
# Batch 330:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 2])
# Batch 331:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 2])
# Batch 332:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 2, 0])
# Batch 333:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 4])
# Batch 334:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 0, 2])
# Batch 335:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 2])
# Batch 336:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 2])
# Batch 337:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 2, 4])
# Batch 338:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 1])
# Batch 339:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 1])
# Batch 340:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 1])
# Batch 341:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 2])
# Batch 342:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 4])
# Batch 343:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 3])
# Batch 344:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 2])
# Batch 345:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 1])
# Batch 346:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 1])
# Batch 347:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 0])
# Batch 348:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 2, 2])
# Batch 349:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 4, 3])
# Batch 350:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 0])
# Batch 351:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 0])
# Batch 352:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 1])
# Batch 353:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 1, 0])
# Batch 354:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 0, 1])
# Batch 355:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 2, 1])
# Batch 356:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 3])
# Batch 357:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 1, 0])
# Batch 358:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 3, 0])
# Batch 359:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 1])
# Batch 360:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 3])
# Batch 361:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 3])
# Batch 362:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 0, 3])
# Batch 363:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 2])
# Batch 364:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 1, 0])
# Batch 365:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 3])
# Batch 366:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 3])
# Batch 367:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 3, 3])
# Batch 368:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 2])
# Batch 369:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 4])
# Batch 370:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 0])
# Batch 371:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 0])
# Batch 372:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 3, 0])
# Batch 373:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 3, 0])
# Batch 374:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 2, 1])
# Batch 375:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 3])
# Batch 376:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 2, 0])
# Batch 377:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 1, 1])
# Batch 378:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 1])
# Batch 379:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 0])
# Batch 380:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 1, 2])
# Batch 381:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 0, 3])
# Batch 382:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 0, 2])
# Batch 383:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 2, 2])
# Batch 384:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 1, 2])
# Batch 385:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 3])
# Batch 386:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 2])
# Batch 387:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 4])
# Batch 388:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 3])
# Batch 389:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 4, 4])
# Batch 390:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 4])
# Batch 391:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 3, 4])
# Batch 392:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 4])
# Batch 393:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 4, 0])
# Batch 394:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 2, 0])
# Batch 395:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 3, 0])
# Batch 396:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 397:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 4, 0])
# Batch 398:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 2])
# Batch 399:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 2])
# Batch 400:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 3])
# Batch 401:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 3, 4])
# Batch 402:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 4])
# Batch 403:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 3])
# Batch 404:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 0, 4])
# Batch 405:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 4, 2])
# Batch 406:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 2, 2])
# Batch 407:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 3, 2])
# Batch 408:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 2])
# Batch 409:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 3])
# Batch 410:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 4])
# Batch 411:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 4, 1])
# Batch 412:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 4, 0])
# Batch 413:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 0])
# Batch 414:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 3, 2])
# Batch 415:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 3])
# Batch 416:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 3])
# Batch 417:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 0])
# Batch 418:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 419:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 3, 1])
# Batch 420:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 3])
# Batch 421:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 1])
# Batch 422:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 3, 2])
# Batch 423:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 1, 4])
# Batch 424:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 0, 1])
# Batch 425:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 2])
# Batch 426:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 2, 3])
# Batch 427:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 3])
# Batch 428:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 0, 0])
# Batch 429:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 3, 0])
# Batch 430:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 0, 0])
# Batch 431:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 2])
# Batch 432:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 0])
# Batch 433:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 4])
# Batch 434:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 4])
# Batch 435:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 4])
# Batch 436:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 4])
# Batch 437:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 1])
# Batch 438:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 2, 1])
# Batch 439:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 2])
# Batch 440:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 2])
# Batch 441:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 0])
# Batch 442:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 3, 2])
# Batch 443:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 2, 2, 3])
# Batch 444:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 1, 1, 1])
# Batch 445:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 1])
# Batch 446:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 2])
# Batch 447:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 1])
# Batch 448:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 1])
# Batch 449:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 2, 0])
# Batch 450:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 3, 4])
# Batch 451:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 2, 1])
# Batch 452:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 3])
# Batch 453:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 2, 0])
# Batch 454:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 0, 3])
# Batch 455:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 0, 0, 0])
# Batch 456:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 2])
# Batch 457:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 2])
# Batch 458:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 4, 3])
# Batch 459:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 0, 1])
# Batch 460:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 4, 3])
# Batch 461:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 3, 1, 4])
# Batch 462:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 3, 0])
# Batch 463:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 1, 0])
# Batch 464:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 4, 0])
# Batch 465:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 3, 2, 2])
# Batch 466:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 0, 4, 4])
# Batch 467:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 2, 2])
# Batch 468:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 0, 2])
# Batch 469:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 0, 2])
# Batch 470:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 3, 0])
# Batch 471:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 1, 3])
# Batch 472:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 2, 1, 3])
# Batch 473:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 0, 3])
# Batch 474:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 1, 2, 3])
# Batch 475:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 1, 0])
# Batch 476:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 3, 1, 2])
# Batch 477:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 4, 3])
# Batch 478:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 4, 3, 2])
# Batch 479:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 3])
# Batch 480:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 3, 4, 0])
# Batch 481:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 4, 4, 0])
# Batch 482:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 4, 1, 0])
# Batch 483:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 3])
# Batch 484:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 1, 4, 4])
# Batch 485:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 4, 1])
# Batch 486:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 1, 0])
# Batch 487:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 2])
# Batch 488:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 3, 2, 3])
# Batch 489:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 4, 1, 2])
# Batch 490:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 1, 0])
# Batch 491:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 0, 1, 0])
# Batch 492:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 4, 0])
# Batch 493:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 0, 4, 1])
# Batch 494:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 2, 2, 1])
# Batch 495:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 4, 0, 4])
# Batch 496:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([3, 0, 1, 0])
# Batch 497:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([0, 1, 1, 3])
# Batch 498:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([2, 1, 0, 4])
# Batch 499:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([1, 2, 4, 3])
# Batch 500:
# Images shape: torch.Size([4, 3, 224, 224])
# Labels: tensor([4, 2, 3, 1])

# %%
trainset_to_label = {0: '1', 1: '2', 2: '3', 3: '4', 4: '5'}

def imshow(inp, title=None):
    """Display image for Tensor."""

    plt.figure(figsize=(12, 8))
    inp = inp.numpy().transpose((1, 2, 0))  # Convert tensor to numpy and adjust dimensions for plt.imshow
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.axis('off')  # Turn off axis
    plt.pause(0.001)  # Pause to allow display update

# Get batch of images and labels from your DataLoader
train_loader_for_vis = DataLoader(train_dataset, batch_size=7, shuffle=True, num_workers=0, collate_fn=custom_collate_fn)
inputs, labels = next(iter(train_loader_for_vis))  # Assume the second item in batch is labels

# Create a grid of the images
out = torchvision.utils.make_grid(inputs)

# Convert labels to readable titles
titles = [trainset_to_label.get(label.item(), 'Unknown') for label in labels]  # Use integer labels directly

# Visualize the grid of images with the mapped class names as titles
imshow(out, title=', '.join(titles))

# %% [markdown]
# Model Building

# %%
from torchvision import models
from torchvision.models import resnet50
import time
# !pip install torchsummary
from torchsummary import summary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
model = models.mobilenet_v3_small(pretrained=True)

# Modify the classifier to match the number of classes in your dataset
num_classes = 5
model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████| 9.83M/9.83M [00:00<00:00, 84.1MB/s]
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1024, out_features=5, bias=True)
#   )
# )

# %%
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          Hardswish-3         [-1, 16, 112, 112]               0
#             Conv2d-4           [-1, 16, 56, 56]             144
#        BatchNorm2d-5           [-1, 16, 56, 56]              32
#               ReLU-6           [-1, 16, 56, 56]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#       Hardsigmoid-11             [-1, 16, 1, 1]               0
# SqueezeExcitation-12           [-1, 16, 56, 56]               0
#            Conv2d-13           [-1, 16, 56, 56]             256
#       BatchNorm2d-14           [-1, 16, 56, 56]              32
#  InvertedResidual-15           [-1, 16, 56, 56]               0
#            Conv2d-16           [-1, 72, 56, 56]           1,152
#       BatchNorm2d-17           [-1, 72, 56, 56]             144
#              ReLU-18           [-1, 72, 56, 56]               0
#            Conv2d-19           [-1, 72, 28, 28]             648
#       BatchNorm2d-20           [-1, 72, 28, 28]             144
#              ReLU-21           [-1, 72, 28, 28]               0
#            Conv2d-22           [-1, 24, 28, 28]           1,728
#       BatchNorm2d-23           [-1, 24, 28, 28]              48
#  InvertedResidual-24           [-1, 24, 28, 28]               0
#            Conv2d-25           [-1, 88, 28, 28]           2,112
#       BatchNorm2d-26           [-1, 88, 28, 28]             176
#              ReLU-27           [-1, 88, 28, 28]               0
#            Conv2d-28           [-1, 88, 28, 28]             792
#       BatchNorm2d-29           [-1, 88, 28, 28]             176
#              ReLU-30           [-1, 88, 28, 28]               0
#            Conv2d-31           [-1, 24, 28, 28]           2,112
#       BatchNorm2d-32           [-1, 24, 28, 28]              48
#  InvertedResidual-33           [-1, 24, 28, 28]               0
#            Conv2d-34           [-1, 96, 28, 28]           2,304
#       BatchNorm2d-35           [-1, 96, 28, 28]             192
#         Hardswish-36           [-1, 96, 28, 28]               0
#            Conv2d-37           [-1, 96, 14, 14]           2,400
#       BatchNorm2d-38           [-1, 96, 14, 14]             192
#         Hardswish-39           [-1, 96, 14, 14]               0
# AdaptiveAvgPool2d-40             [-1, 96, 1, 1]               0
#            Conv2d-41             [-1, 24, 1, 1]           2,328
#              ReLU-42             [-1, 24, 1, 1]               0
#            Conv2d-43             [-1, 96, 1, 1]           2,400
#       Hardsigmoid-44             [-1, 96, 1, 1]               0
# SqueezeExcitation-45           [-1, 96, 14, 14]               0
#            Conv2d-46           [-1, 40, 14, 14]           3,840
#       BatchNorm2d-47           [-1, 40, 14, 14]              80
#  InvertedResidual-48           [-1, 40, 14, 14]               0
#            Conv2d-49          [-1, 240, 14, 14]           9,600
#       BatchNorm2d-50          [-1, 240, 14, 14]             480
#         Hardswish-51          [-1, 240, 14, 14]               0
#            Conv2d-52          [-1, 240, 14, 14]           6,000
#       BatchNorm2d-53          [-1, 240, 14, 14]             480
#         Hardswish-54          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-55            [-1, 240, 1, 1]               0
#            Conv2d-56             [-1, 64, 1, 1]          15,424
#              ReLU-57             [-1, 64, 1, 1]               0
#            Conv2d-58            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-59            [-1, 240, 1, 1]               0
# SqueezeExcitation-60          [-1, 240, 14, 14]               0
#            Conv2d-61           [-1, 40, 14, 14]           9,600
#       BatchNorm2d-62           [-1, 40, 14, 14]              80
#  InvertedResidual-63           [-1, 40, 14, 14]               0
#            Conv2d-64          [-1, 240, 14, 14]           9,600
#       BatchNorm2d-65          [-1, 240, 14, 14]             480
#         Hardswish-66          [-1, 240, 14, 14]               0
#            Conv2d-67          [-1, 240, 14, 14]           6,000
#       BatchNorm2d-68          [-1, 240, 14, 14]             480
#         Hardswish-69          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-70            [-1, 240, 1, 1]               0
#            Conv2d-71             [-1, 64, 1, 1]          15,424
#              ReLU-72             [-1, 64, 1, 1]               0
#            Conv2d-73            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-74            [-1, 240, 1, 1]               0
# SqueezeExcitation-75          [-1, 240, 14, 14]               0
#            Conv2d-76           [-1, 40, 14, 14]           9,600
#       BatchNorm2d-77           [-1, 40, 14, 14]              80
#  InvertedResidual-78           [-1, 40, 14, 14]               0
#            Conv2d-79          [-1, 120, 14, 14]           4,800
#       BatchNorm2d-80          [-1, 120, 14, 14]             240
#         Hardswish-81          [-1, 120, 14, 14]               0
#            Conv2d-82          [-1, 120, 14, 14]           3,000
#       BatchNorm2d-83          [-1, 120, 14, 14]             240
#         Hardswish-84          [-1, 120, 14, 14]               0
# AdaptiveAvgPool2d-85            [-1, 120, 1, 1]               0
#            Conv2d-86             [-1, 32, 1, 1]           3,872
#              ReLU-87             [-1, 32, 1, 1]               0
#            Conv2d-88            [-1, 120, 1, 1]           3,960
#       Hardsigmoid-89            [-1, 120, 1, 1]               0
# SqueezeExcitation-90          [-1, 120, 14, 14]               0
#            Conv2d-91           [-1, 48, 14, 14]           5,760
#       BatchNorm2d-92           [-1, 48, 14, 14]              96
#  InvertedResidual-93           [-1, 48, 14, 14]               0
#            Conv2d-94          [-1, 144, 14, 14]           6,912
#       BatchNorm2d-95          [-1, 144, 14, 14]             288
#         Hardswish-96          [-1, 144, 14, 14]               0
#            Conv2d-97          [-1, 144, 14, 14]           3,600
#       BatchNorm2d-98          [-1, 144, 14, 14]             288
#         Hardswish-99          [-1, 144, 14, 14]               0
# AdaptiveAvgPool2d-100            [-1, 144, 1, 1]               0
#           Conv2d-101             [-1, 40, 1, 1]           5,800
#             ReLU-102             [-1, 40, 1, 1]               0
#           Conv2d-103            [-1, 144, 1, 1]           5,904
#      Hardsigmoid-104            [-1, 144, 1, 1]               0
# SqueezeExcitation-105          [-1, 144, 14, 14]               0
#           Conv2d-106           [-1, 48, 14, 14]           6,912
#      BatchNorm2d-107           [-1, 48, 14, 14]              96
# InvertedResidual-108           [-1, 48, 14, 14]               0
#           Conv2d-109          [-1, 288, 14, 14]          13,824
#      BatchNorm2d-110          [-1, 288, 14, 14]             576
#        Hardswish-111          [-1, 288, 14, 14]               0
#           Conv2d-112            [-1, 288, 7, 7]           7,200
#      BatchNorm2d-113            [-1, 288, 7, 7]             576
#        Hardswish-114            [-1, 288, 7, 7]               0
# AdaptiveAvgPool2d-115            [-1, 288, 1, 1]               0
#           Conv2d-116             [-1, 72, 1, 1]          20,808
#             ReLU-117             [-1, 72, 1, 1]               0
#           Conv2d-118            [-1, 288, 1, 1]          21,024
#      Hardsigmoid-119            [-1, 288, 1, 1]               0
# SqueezeExcitation-120            [-1, 288, 7, 7]               0
#           Conv2d-121             [-1, 96, 7, 7]          27,648
#      BatchNorm2d-122             [-1, 96, 7, 7]             192
# InvertedResidual-123             [-1, 96, 7, 7]               0
#           Conv2d-124            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-125            [-1, 576, 7, 7]           1,152
#        Hardswish-126            [-1, 576, 7, 7]               0
#           Conv2d-127            [-1, 576, 7, 7]          14,400
#      BatchNorm2d-128            [-1, 576, 7, 7]           1,152
#        Hardswish-129            [-1, 576, 7, 7]               0
# AdaptiveAvgPool2d-130            [-1, 576, 1, 1]               0
#           Conv2d-131            [-1, 144, 1, 1]          83,088
#             ReLU-132            [-1, 144, 1, 1]               0
#           Conv2d-133            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-134            [-1, 576, 1, 1]               0
# SqueezeExcitation-135            [-1, 576, 7, 7]               0
#           Conv2d-136             [-1, 96, 7, 7]          55,296
#      BatchNorm2d-137             [-1, 96, 7, 7]             192
# InvertedResidual-138             [-1, 96, 7, 7]               0
#           Conv2d-139            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-140            [-1, 576, 7, 7]           1,152
#        Hardswish-141            [-1, 576, 7, 7]               0
#           Conv2d-142            [-1, 576, 7, 7]          14,400
#      BatchNorm2d-143            [-1, 576, 7, 7]           1,152
#        Hardswish-144            [-1, 576, 7, 7]               0
# AdaptiveAvgPool2d-145            [-1, 576, 1, 1]               0
#           Conv2d-146            [-1, 144, 1, 1]          83,088
#             ReLU-147            [-1, 144, 1, 1]               0
#           Conv2d-148            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-149            [-1, 576, 1, 1]               0
# SqueezeExcitation-150            [-1, 576, 7, 7]               0
#           Conv2d-151             [-1, 96, 7, 7]          55,296
#      BatchNorm2d-152             [-1, 96, 7, 7]             192
# InvertedResidual-153             [-1, 96, 7, 7]               0
#           Conv2d-154            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-155            [-1, 576, 7, 7]           1,152
#        Hardswish-156            [-1, 576, 7, 7]               0
# AdaptiveAvgPool2d-157            [-1, 576, 1, 1]               0
#           Linear-158                 [-1, 1024]         590,848
#        Hardswish-159                 [-1, 1024]               0
#          Dropout-160                 [-1, 1024]               0
#           Linear-161                    [-1, 5]           5,125
# ================================================================
# Total params: 1,522,981
# Trainable params: 1,522,981
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 34.60
# Params size (MB): 5.81
# Estimated Total Size (MB): 40.99
# ----------------------------------------------------------------

# %% [markdown]
# Defining Loss and Optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0004)

# %% [markdown]
# Training and Validation Loop

# %%
# The number of training epochs.
n_epochs = 50

# These are used to record information
best_valid_acc = 0
train_loss_epochs = []
train_acc_epochs = []
valid_loss_epochs = []
valid_acc_epochs = []

for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []

    # Iterate the training set by batches.
    for batch in tqdm(train_loader):

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        imgs = imgs.to(device)
        labels = labels.to(device)

        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs)

        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = criterion(logits, labels)

        # Compute the gradients for parameters.
        loss.backward()

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc.item())

    # The average loss and accuracy of the training set is the average of the recorded values.
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)
    train_loss_epochs.append(train_loss)
    train_acc_epochs.append(train_acc)

    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in tqdm(valid_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        imgs = imgs.to(device)
        labels = labels.to(device)

        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
          logits = model(imgs)

        # We can still compute the loss (but not the gradient).
        loss = criterion(logits, labels)

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc.item())

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)
    valid_loss_epochs.append(valid_loss)
    valid_acc_epochs.append(valid_acc)

    # save the best model
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc
        torch.save(model.state_dict(), 'best_model.pth')

    # Print the information.
    print(f"[Epoch: {epoch + 1:03d}/{n_epochs:03d}] Train: loss={train_loss:.5f}, acc={train_acc:.5f} | Valid: loss={valid_loss:.5f}, acc={valid_acc:.5f}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 001/050] Train: loss=1.35479, acc=0.42000 | Valid: loss=1.20128, acc=0.50000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 002/050] Train: loss=1.33775, acc=0.42250 | Valid: loss=1.18496, acc=0.49000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 003/050] Train: loss=1.33531, acc=0.42750 | Valid: loss=1.16776, acc=0.50500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 004/050] Train: loss=1.31365, acc=0.44800 | Valid: loss=1.16430, acc=0.51250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 005/050] Train: loss=1.29293, acc=0.46900 | Valid: loss=1.16270, acc=0.50250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 006/050] Train: loss=1.30185, acc=0.44250 | Valid: loss=1.14626, acc=0.50000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 007/050] Train: loss=1.28947, acc=0.45750 | Valid: loss=1.13469, acc=0.50000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 008/050] Train: loss=1.30300, acc=0.46250 | Valid: loss=1.13539, acc=0.51500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 009/050] Train: loss=1.27882, acc=0.45950 | Valid: loss=1.12929, acc=0.51500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 010/050] Train: loss=1.27338, acc=0.46950 | Valid: loss=1.10097, acc=0.52500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 011/050] Train: loss=1.25327, acc=0.48000 | Valid: loss=1.11037, acc=0.51500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 012/050] Train: loss=1.26001, acc=0.46600 | Valid: loss=1.09723, acc=0.52250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 013/050] Train: loss=1.22189, acc=0.50050 | Valid: loss=1.08267, acc=0.53750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 014/050] Train: loss=1.24318, acc=0.47250 | Valid: loss=1.08797, acc=0.51750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 015/050] Train: loss=1.21002, acc=0.49650 | Valid: loss=1.08456, acc=0.53000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 016/050] Train: loss=1.22834, acc=0.48850 | Valid: loss=1.06647, acc=0.53500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 017/050] Train: loss=1.24065, acc=0.48150 | Valid: loss=1.06816, acc=0.52250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 018/050] Train: loss=1.23336, acc=0.47950 | Valid: loss=1.04504, acc=0.54500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 019/050] Train: loss=1.20074, acc=0.50200 | Valid: loss=1.03010, acc=0.54000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 020/050] Train: loss=1.20088, acc=0.50050 | Valid: loss=1.02806, acc=0.54500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 021/050] Train: loss=1.19369, acc=0.50900 | Valid: loss=1.04291, acc=0.56250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 022/050] Train: loss=1.16580, acc=0.51500 | Valid: loss=1.00974, acc=0.56750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 023/050] Train: loss=1.16590, acc=0.51950 | Valid: loss=1.02594, acc=0.56000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 024/050] Train: loss=1.17183, acc=0.51450 | Valid: loss=1.01911, acc=0.55250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 025/050] Train: loss=1.16426, acc=0.52650 | Valid: loss=1.01281, acc=0.54750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 026/050] Train: loss=1.14592, acc=0.53200 | Valid: loss=0.99435, acc=0.56750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 027/050] Train: loss=1.16377, acc=0.52750 | Valid: loss=0.97981, acc=0.57750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 028/050] Train: loss=1.15641, acc=0.52550 | Valid: loss=0.95786, acc=0.57250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 029/050] Train: loss=1.12215, acc=0.52650 | Valid: loss=0.96115, acc=0.57750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 030/050] Train: loss=1.13237, acc=0.54450 | Valid: loss=0.98560, acc=0.56500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 031/050] Train: loss=1.14341, acc=0.53000 | Valid: loss=0.97074, acc=0.59250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 032/050] Train: loss=1.10471, acc=0.54400 | Valid: loss=0.95464, acc=0.58500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 033/050] Train: loss=1.12637, acc=0.53350 | Valid: loss=0.95025, acc=0.59750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 034/050] Train: loss=1.10115, acc=0.54550 | Valid: loss=0.94625, acc=0.58750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 035/050] Train: loss=1.07774, acc=0.56700 | Valid: loss=0.95333, acc=0.59000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 036/050] Train: loss=1.09069, acc=0.55300 | Valid: loss=0.91957, acc=0.58750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 037/050] Train: loss=1.07578, acc=0.55150 | Valid: loss=0.91410, acc=0.59000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 038/050] Train: loss=1.07210, acc=0.58350 | Valid: loss=0.92141, acc=0.58750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 039/050] Train: loss=1.08434, acc=0.56050 | Valid: loss=0.91612, acc=0.59250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 040/050] Train: loss=1.07381, acc=0.55700 | Valid: loss=0.91248, acc=0.58000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 041/050] Train: loss=1.03710, acc=0.58150 | Valid: loss=0.88553, acc=0.62500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 042/050] Train: loss=1.03377, acc=0.59000 | Valid: loss=0.89052, acc=0.61500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 043/050] Train: loss=1.02723, acc=0.59150 | Valid: loss=0.90461, acc=0.61250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 044/050] Train: loss=1.03664, acc=0.57600 | Valid: loss=0.88286, acc=0.62500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 045/050] Train: loss=1.03813, acc=0.57600 | Valid: loss=0.84722, acc=0.63750
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 046/050] Train: loss=1.02024, acc=0.58600 | Valid: loss=0.86394, acc=0.62500
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 047/050] Train: loss=1.01173, acc=0.58900 | Valid: loss=0.85020, acc=0.62250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 048/050] Train: loss=0.98852, acc=0.59250 | Valid: loss=0.85167, acc=0.62250
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 049/050] Train: loss=1.00991, acc=0.57200 | Valid: loss=0.82427, acc=0.64000
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch: 050/050] Train: loss=0.96647, acc=0.61800 | Valid: loss=0.82834, acc=0.62500

# %%
# Plotting the loss curves
plt.figure()
plt.plot(train_loss_epochs, label='Train Loss')
plt.plot(valid_loss_epochs, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# Plotting the accuracy curves
plt.figure()
plt.plot(train_acc_epochs, label='Train Accuracy')
plt.plot(valid_acc_epochs, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train and Validation Accuracy')
plt.legend()
plt.show()

# %%
# load best model weights
model.load_state_dict(torch.load('best_model.pth'))

# Make sure the model is in eval mode.
# Some modules like Dropout or BatchNorm affect if the model is in training mode.
model.eval()

test_accs = []

# Iterate the testing set by batches.
for batch in tqdm(test_loader):
    # A batch consists of image data and corresponding labels.
    imgs, labels = batch
    imgs = imgs.to(device)
    labels = labels.to(device)

    # We don't need gradient in test
    # Using torch.no_grad() accelerates the forward process.
    with torch.no_grad():
      logits = model(imgs)

    # We can still compute the loss (but not the gradient).
    loss = criterion(logits, labels)

    # Compute the accuracy for current batch.
    acc = (logits.argmax(dim=-1) == labels).float().mean()

    # Record accuracy.
    test_accs.append(acc)

# The average accuracy for entire test set is the average of the recorded values.
test_acc = sum(test_accs) / len(test_accs)
print(f'Test accuracy {test_acc}')
# Out:
# <ipython-input-31-7201ed175c95>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
#   0%|          | 0/100 [00:00<?, ?it/s]
# Test accuracy 0.699999988079071

# %% [markdown]
# Evaluation Metrics

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
model.eval()
all_labels = []
all_preds = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)

# %%
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Accuracy: 0.7
# Precision: 0.7010091612325983
# Recall: 0.7

# %%
class_names = ['one', 'two', 'three', 'four', 'five']

# Initialize lists to hold all predictions and ground-truth labels
all_preds = []
all_labels = []

# Ensure model is in evaluation mode
model.eval()

# Disable gradient calculation for faster computations
with torch.no_grad():
    for inputs, labels in test_loader:  # Use your test DataLoader here
        inputs = inputs.to(device)  # Move inputs to the correct device (CPU/GPU)
        labels = labels.to(device)  # Move labels to the correct device

        # Forward pass: get predictions
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)  # Get the class with the highest score

        # Collect predictions and labels
        all_preds.append(preds.to(device))  # Keep predictions on the GPU
        all_labels.append(labels.to(device))  # Keep labels on the GPU

# Convert lists to tensors, then move to the correct device
all_preds = torch.cat(all_preds).to(device)  # Concatenate and keep on GPU
all_labels = torch.cat(all_labels).to(device)  # Concatenate and keep on GPU

# Compute confusion matrix (move to CPU for sklearn compatibility)
cm = confusion_matrix(all_labels.cpu().numpy(), all_preds.cpu().numpy())

# Display the confusion matrix using sklearn's ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)

plt.title('Confusion Matrix (Test Set)')
plt.show()

# %% [markdown]
# Measuring Time and Memory Usage

# %%
def measure_time_and_memory(model, data_loader, criterion, optimizer=None, device='cuda'):
    """
    Measure the average time and memory usage for training or validation/testing.
    If optimizer is provided, it's for training; otherwise, it's for validation/testing.
    """
    model.to(device)
    total_time = 0.0
    total_memory = 0.0
    total_batches = 0

    # Ensure model is in training mode if optimizer is provided
    model.train() if optimizer else model.eval()

    # Disable gradient calculation for validation and testing
    with torch.no_grad() if not optimizer else torch.enable_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            start_time = time.time()  # Start time measurement

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            if optimizer:
                optimizer.zero_grad()
                loss.backward()  # Only needed during training
                optimizer.step()  # Update weights

            end_time = time.time()  # End time measurement

            # Measure memory usage
            memory_usage = torch.cuda.memory_allocated(device) / (1024 * 1024)  # in MB

            total_time += (end_time - start_time)
            total_memory += memory_usage
            total_batches += 1

    average_time = total_time / total_batches if total_batches > 0 else 0
    average_memory = total_memory / total_batches if total_batches > 0 else 0

    return average_time, average_memory


device = 'cuda' if torch.cuda.is_available() else 'cpu'  # Set device to CUDA or CPU based on availability
train_average_time, train_average_memory = measure_time_and_memory(model, train_loader, criterion, optimizer, device)
val_average_time, val_average_memory = measure_time_and_memory(model, valid_loader, criterion, device=device)
test_average_time, test_average_memory = measure_time_and_memory(model, test_loader, criterion, device=device)

print(f"Average Training Time: {train_average_time:.4f} seconds, Average Memory Usage: {train_average_memory:.2f} MB")
print(f"Average Validation Time: {val_average_time:.4f} seconds, Average Memory Usage: {val_average_memory:.2f} MB")
print(f"Average Testing Time: {test_average_time:.4f} seconds, Average Memory Usage: {test_average_memory:.2f} MB")
# Out:
# Average Training Time: 0.0198 seconds, Average Memory Usage: 35.39 MB
# Average Validation Time: 0.0063 seconds, Average Memory Usage: 35.39 MB
# Average Testing Time: 0.0061 seconds, Average Memory Usage: 35.39 MB
